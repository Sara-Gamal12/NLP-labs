# %%
# Type your full name
student1_full_name = "Eman Ibrahim"

# Type your section 1 or 2
student1_section = "1"

# Type your BN
student1_BN = "14"

###########################################
# Type your full name
student2_full_name = "Sara Gamal"

# Type your section 1 or 2
student2_section = "1"

# Type your BN
student2_BN = "20"

# %%
import re
# if you don't have pandas, uncomment the next line
# !pip install pandas
import pandas as pd

# %% [markdown]
# # Task Description
#
# In this task, you will work with text file containing several emails with their body and other information like sender email, date, subject etc...
#
# Dataset Link: https://www.kaggle.com/datasets/rtatman/fraudulent-email-corpus
#
# Download the dataset then rename the text file to: emails_dataset.txt
#
# The goal of this requirement is to process this text file to convert it to a pandas dataframe to be used easily later. First of all, you need open the text file and try to familiarize yourself with it.
#
# Your task will be implementing the TODOs only. Don't write any code out side the TODOs or change other code of this notebook. You will also need to run all the cells in sequence to produce the final output file to be submitted.

# %%
# Let's read the emails text file
f = open(r"emails_dataset.txt", "r").read()
print(type(f))
# Out:
# <class 'str'>

# %% [markdown]
# Now, we have the whole emails in one string. The first thing we need to do is to split this string to a list containing separate emails. To do this you need to discover the text file. You will notice that every email always starts by a fixed pattern. Your task is to discover what this pattern is to split the string on.

# %%
######################### TODO: write the pattern to split the emails on in the raw string below ######################
start_email_pattern = r"\bFrom r\b"
#######################################################################################################################

contents = re.split(start_email_pattern, f)
contents.pop(0)
assert len(contents) == 3976, "Your pattern is wrong"

# %% [markdown]
# # Information to be collected
#
# Since we now have a list with all emails, we can iterate over them to collect the information we need. Your task will be to implement some functions using Regular Expressions to collect the following information:
# 1. Sender Email
# 2. Sender Name
# 3. Recipient Email
# 4. Recipient Name
# 5. Date
# 6. Subject

# %%
# This function takes a full email (from the contents list)
# and returns both the sender email and name as strings
# To deremine this, look at the original text file and answer the following questions
# what is the pattern that start the line containing both sender name and email?
# If you get this whole line, how to capture the email?
# If you get this whole line, how to capture the name?

def senderEmailAndName(email_item):
    ###################### TODO: write regex that can match the whole line containing the sender name and email #########
    sender_name_email_line_regex = r"(?<=\nFrom: ).*\n"
    #####################################################################################################################
    sender = re.search(sender_name_email_line_regex, email_item)
    # This check is in case there is no sender found (We don't know if all emails contain this info)
    if sender is not None:
        # Since we have the line You need to do the following
        # You can capture the email by using only one regex (only one re.search())
        # To capture the name safely you can write regex that captures all characters from the end of the start line pattern
        # to the pattern the starts the email
        
        ######################### TODO: write regex that captures the email, and the name #############################
        # email regex: this will capture the email exactly
        email_regex = r"\b[a-zA-Z0-9%._-]+@[a-zA-Z0-9._-]+   (\.[a-zA-z]{2,})?   \b"
        # name regex: this will capture the name besides some characters before and after it that will be removed later
        name_regex = r".*(?=<)"
        ##############################################################################################################
        s_email = re.search(email_regex, sender.group())
        s_name = re.search(name_regex, sender.group())
    else:
        s_email = None
        s_name = None

    # We need to check as re.search() may return None
    if s_email is not None:
        sender_email = s_email.group()
    else:
        sender_email = None

    # We need to check as re.search() may return None
    if s_name is not None:
        # Since the name is not captured exactly, we need to substitute all unneeded characters
        
        ############################# TODO: write regex to capture characters to be removed #####################
        characters_remove_from_beginning = r'^\W+'
        characters_remove_from_end = r'\W+$'
        #########################################################################################################
        sender_name = re.sub(characters_remove_from_end, "", re.sub(characters_remove_from_beginning, "", s_name.group()))
    else:
        sender_name = None

    return sender_email, sender_name
senderEmailAndName("From:gkgl <s@gmail.com>\n")
# Out:
# (None, None)

# %%
# This function takes a full email (from the contents list)
# and returns both the recipient email and name as strings
# You will do exactly the same thing you did for sender email except for the pattern used to capture the line
# containing the recipient

def recipientEmailAndName(email_item):
    ###################### TODO: write regex that can match the whole line containing the recipient name and email #########
    recipient_name_email_line_regex = r"(?<=\nTo:).*\n"
    #####################################################################################################################
    recipient = re.search(recipient_name_email_line_regex, email_item)
    print(recipient)

    # This check is in case there is no sender found (We don't know if all emails contain this info)
    if recipient is not None:
        # Since we have the line You need to do the following
        # You can capture the email by using only one regex (only one re.search())
        # To capture the name safely you can write regex that captures all characters from the end of the start line pattern
        # to the pattern the starts the email
        
        ######################### TODO: write regex that captures the email, and the name #############################
        # email regex: this will capture the email exactly
        email_regex = r"\b[a-zA-Z0-9%._-]+@[a-zA-Z0-9._-]+(\.[a-zA-z]{2,})?\b"
        # name regex: this will capture the name besides some characters before and after it that will be removed later
        name_regex = r"(.+(?=@))|(.+(?=<))"
        ##############################################################################################################
        r_email = re.search(email_regex, recipient.group())
        r_name = re.search(name_regex, recipient.group())
    else:
        r_email = None
        r_name = None

    # We need to check as re.search() may return None
    if r_email is not None:
        recipient_email = r_email.group()
    else:
        recipient_email = None

    # We need to check as re.search() may return None
    if r_name is not None:
        # Since the name is not captured exactly, we need to substitute all unneeded characters
        
        ############################# TODO: write regex to capture characters to be removed #####################
        characters_remove_from_beginning = r'^\W+'
        characters_remove_from_end = r'\W+$'
        #########################################################################################################
        recipient_name = re.sub(characters_remove_from_end, "", re.sub(characters_remove_from_beginning, "", r_name.group()))
    else:
        recipient_name = None

    return recipient_email, recipient_name
recipientEmailAndName("\nTo: spencer_taylor2@yahoo.com.au\n")
# Out:
# <re.Match object; span=(4, 34), match=' spencer_taylor2@yahoo.com.au\n'>
# ('spencer_taylor2@yahoo.com.au', 'spencer_taylor2')

# %%
# This function takes a full email and returns a string with the date

def getDate(email_item):
    ########################### TODO: write regex to match the whole line containing the date ########################
    line_date_regex = r"(?<=\nDate:).*\n"
    ##################################################################################################################
    date_field = re.search(line_date_regex, email_item)

    if date_field is not None:
        #################################### TODO: write regex to match only the date ###############################
        # e.g. If the date is: Thu, 31 Oct 2002 22:17:55 +0100
        # you need to match only 31 Oct 2002
        date_only_regex = r"\b[0-9]{1,2}\s[a-zA-Z]{3}\s[0-9]{4}\b"
        #############################################################################################################
        date = re.search(date_only_regex, date_field.group())
    else:
        date = None

    if date is not None:
        date_sent = date.group()
    else:
        date_sent = None

    return date_sent
getDate(contents[0])
# Out:
# '31 Oct 2002'

# %%
# This function takes a full email item and returns a string with the email subject
def getSubject(email_item):
    ########################## TODO: write regex to match the whole line containing the subject #################
    line_subject_regex = r"(?<=\nSubject: ).*\n"
    #############################################################################################################
    subject_field = re.search(line_subject_regex, email_item)

    if subject_field is not None:
        #################### TODO: write regex with the pattern to be removed to capture the subject only ##########
        remove_pattern = r"^\W+|\W+$"
        ############################################################################################################
        subject = re.sub(remove_pattern, "", subject_field.group())
    else:
        subject = None

    return subject
getSubject(contents[0])
# Out:
# 'URGENT BUSINESS ASSISTANCE AND PARTNERSHIP'

# %%
# Let's construct our emails
emails = []
for email_item in contents:
    emails_dict = {}
    emails_dict["sender_email"], emails_dict["sender_name"] = senderEmailAndName(email_item)
    emails_dict["recipient_email"], emails_dict["recipient_name"] = recipientEmailAndName(email_item)
    emails_dict["date_sent"] = getDate(email_item)
    emails_dict["subject"] = getSubject(email_item)
    
    emails.append(emails_dict)
    
assert len(emails) == 3976, "You have something wrong"
# Out:
# <re.Match object; span=(280, 302), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(288, 293), match=' R@M\n'>
# <re.Match object; span=(264, 286), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(265, 287), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(256, 261), match=' R@M\n'>
# <re.Match object; span=(217, 238), match=' davidkuta@yahoo.com\n'>
# None
# <re.Match object; span=(286, 308), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(278, 283), match=' R@M\n'>
# None
# <re.Match object; span=(248, 253), match=' R@E\n'>
# <re.Match object; span=(265, 270), match=' R@M\n'>
# <re.Match object; span=(237, 259), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(248, 253), match=' R@E\n'>
# <re.Match object; span=(260, 282), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(266, 288), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(266, 288), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(390, 424), match=' ntcir-listmem@newns.op.nii.ac.jp\n'>
# <re.Match object; span=(350, 376), match=' ntcir-outgoing@nii.ac.jp\n'>
# <re.Match object; span=(325, 347), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(231, 241), match=' oshea@UM\n'>
# <re.Match object; span=(304, 326), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(416, 438), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(417, 439), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(378, 383), match=' R@M\n'>
# <re.Match object; span=(283, 310), match=' edema_mb@phantomemail.com\n'>
# <re.Match object; span=(276, 303), match=' edema_mb@phantomemail.com\n'>
# <re.Match object; span=(282, 287), match=' R@M\n'>
# <re.Match object; span=(227, 232), match=' R@M\n'>
# <re.Match object; span=(347, 352), match=' R@M\n'>
# <re.Match object; span=(492, 511), match=' obinaokoro@37.com\n'>
# <re.Match object; span=(474, 500), match=' software-seminar@eecs.UM\n'>
# <re.Match object; span=(234, 274), match=' adamuohiroma.adamuohiroma@caramail.com\n'>
# None
# <re.Match object; span=(482, 497), match=' mbengu@37.com\n'>
# <re.Match object; span=(217, 239), match=' mmahoyi@caramail.com\n'>
# <re.Match object; span=(291, 313), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(229, 253), match=' bbell.idr@caramail.com\n'>
# <re.Match object; span=(244, 271), match=' iidris.bello@caramail.com\n'>
# <re.Match object; span=(321, 343), match=' john2002@bluemail.ch\n'>
# <re.Match object; span=(283, 288), match=' R@M\n'>
# <re.Match object; span=(294, 299), match=' R@M\n'>
# <re.Match object; span=(229, 253), match=' bbell.idr@caramail.com\n'>
# <re.Match object; span=(291, 313), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(488, 506), match=' kabila72b@37.com\n'>
# <re.Match object; span=(360, 379), match=' colibri@let.uu.nl\n'>
# <re.Match object; span=(360, 403), match=' feldhausen@linguistics.ruhr-uni-bochum.de\n'>
# <re.Match object; span=(341, 363), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(157, 177), match=' ga_mm1@zwallet.com\n'>
# <re.Match object; span=(261, 268), match=' <R@M>\n'>
# <re.Match object; span=(254, 276), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(255, 277), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(119, 153), match=' williamsdaniel1@phantomemail.com\n'>
# <re.Match object; span=(149, 154), match=' R@E\n'>
# None
# <re.Match object; span=(313, 318), match=' R@M\n'>
# <re.Match object; span=(243, 265), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(243, 265), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(250, 272), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(231, 251), match=' samir@combinet.com\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(228, 233), match=' R@M\n'>
# <re.Match object; span=(186, 213), match=' judeestrada2@dmailman.com\n'>
# <re.Match object; span=(254, 276), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(388, 408), match=' olu@mailservice.ms\n'>
# <re.Match object; span=(239, 285), match=' " resbob@al-islam.com" <resbob@al-islam.com>\n'>
# <re.Match object; span=(275, 297), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(217, 222), match=' R@M\n'>
# <re.Match object; span=(220, 225), match=' R@M\n'>
# <re.Match object; span=(268, 290), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(265, 287), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(228, 233), match=' R@M\n'>
# <re.Match object; span=(253, 275), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(528, 555), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(365, 391), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(153, 174), match=' oluis2@caramail.com\n'>
# <re.Match object; span=(153, 174), match=' oluis2@caramail.com\n'>
# <re.Match object; span=(359, 383), match=' <savimbidenis@www.com>\n'>
# <re.Match object; span=(169, 174), match=' R@M\n'>
# <re.Match object; span=(263, 285), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(266, 288), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(124, 146), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(422, 483), match=' "=?iso-8859-1?Q?lawrence.smith?=" <lawrence.smit>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(388, 407), match=' daninno555@37.com\n'>
# <re.Match object; span=(526, 544), match=' kabila72i@37.com\n'>
# <re.Match object; span=(164, 187), match=' b_kambili@yahoo.co.uk\n'>
# <re.Match object; span=(267, 289), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(453, 480), match=' josephbenson@weedmail.com\n'>
# None
# <re.Match object; span=(383, 403), match=' pat11@weedmail.com\n'>
# <re.Match object; span=(217, 244), match=' felix.lamine@caramail.com\n'>
# <re.Match object; span=(230, 235), match=' R@M\n'>
# <re.Match object; span=(277, 299), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(227, 232), match=' R@M\n'>
# <re.Match object; span=(199, 204), match=' R@S\n'>
# <re.Match object; span=(186, 191), match=' R@M\n'>
# <re.Match object; span=(139, 144), match=' R@S\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(127, 157), match=' stevens.bangura@caramail.com\n'>
# <re.Match object; span=(263, 285), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(253, 275), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(301, 327), match=' frankikpendu3@mail.co.za\n'>
# <re.Match object; span=(194, 225), match=' jeffery_hill10007@hotmail.com\n'>
# <re.Match object; span=(200, 205), match=' R@S\n'>
# <re.Match object; span=(206, 211), match=' R@M\n'>
# <re.Match object; span=(379, 397), match=' samaluko1@37.com\n'>
# <re.Match object; span=(267, 289), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(256, 278), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(256, 278), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(236, 258), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(177, 207), match=' chrisadebayo2002@yahoo.co.uk\n'>
# <re.Match object; span=(161, 185), match=' barr.femi@caramail.com\n'>
# <re.Match object; span=(264, 286), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(226, 231), match=' R@S\n'>
# <re.Match object; span=(229, 234), match=' R@M\n'>
# <re.Match object; span=(70, 98), match=' mikechukwu32@primposta.com\n'>
# <re.Match object; span=(70, 98), match=' mikechukwu32@primposta.com\n'>
# <re.Match object; span=(129, 134), match=' R@M\n'>
# <re.Match object; span=(174, 196), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(129, 134), match=' R@M\n'>
# <re.Match object; span=(174, 196), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(257, 279), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(256, 278), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(224, 229), match=' R@M\n'>
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(193, 198), match=' R@M\n'>
# <re.Match object; span=(170, 175), match=' R@M\n'>
# <re.Match object; span=(110, 140), match=' chiedo_jonathan2@netzero.com\n'>
# <re.Match object; span=(246, 268), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(276, 302), match=' willbanigo003@juntos.com\n'>
# <re.Match object; span=(242, 247), match=' R@M\n'>
# <re.Match object; span=(238, 243), match=' R@M\n'>
# <re.Match object; span=(237, 259), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(203, 225), match=' jisrael2@breathe.com\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(255, 279), match=' wlindner@aclimited.com\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(318, 323), match=' R@M\n'>
# <re.Match object; span=(324, 329), match=' R@M\n'>
# <re.Match object; span=(146, 151), match=' R@S\n'>
# <re.Match object; span=(206, 211), match=' R@S\n'>
# <re.Match object; span=(254, 274), match=' chinaeke7@juno.com\n'>
# <re.Match object; span=(350, 372), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(228, 233), match=' R@E\n'>
# <re.Match object; span=(327, 332), match=' R@M\n'>
# <re.Match object; span=(338, 372), match=' foryourconsumption_2@hotmail.com\n'>
# <re.Match object; span=(302, 307), match=' R@M\n'>
# <re.Match object; span=(319, 324), match=' R@M\n'>
# <re.Match object; span=(331, 336), match=' R@M\n'>
# <re.Match object; span=(367, 387), match=' sameez11@yahoo.com\n'>
# <re.Match object; span=(367, 387), match=' sameez11@yahoo.com\n'>
# <re.Match object; span=(363, 383), match=' sameez11@yahoo.com\n'>
# <re.Match object; span=(363, 383), match=' sameez11@yahoo.com\n'>
# <re.Match object; span=(363, 383), match=' sameez11@yahoo.com\n'>
# <re.Match object; span=(265, 272), match=' <R@M>\n'>
# <re.Match object; span=(155, 173), match=' tundatx@zapo.net\n'>
# <re.Match object; span=(318, 323), match=' R@M\n'>
# <re.Match object; span=(210, 215), match=' R@M\n'>
# <re.Match object; span=(219, 241), match=' jochom12@hotmail.com\n'>
# <re.Match object; span=(187, 192), match=' R@E\n'>
# <re.Match object; span=(187, 192), match=' R@E\n'>
# <re.Match object; span=(209, 214), match=' R@M\n'>
# <re.Match object; span=(200, 221), match=' wbanigo@anfmail.com\n'>
# <re.Match object; span=(199, 204), match=' R@M\n'>
# <re.Match object; span=(165, 170), match=' R@M\n'>
# <re.Match object; span=(303, 308), match=' R@M\n'>
# <re.Match object; span=(130, 157), match=' leezbt_qeen@latinmail.com\n'>
# <re.Match object; span=(158, 181), match=' szpak@site.uottawa.ca\n'>
# <re.Match object; span=(69, 74), match=' R@M\n'>
# <re.Match object; span=(199, 204), match=' R@M\n'>
# <re.Match object; span=(74, 79), match=' R@M\n'>
# <re.Match object; span=(211, 216), match=' R@S\n'>
# <re.Match object; span=(210, 215), match=' R@M\n'>
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(655, 677), match=' PROSODY@list.msu.edu\n'>
# <re.Match object; span=(641, 663), match=' PROSODY@list.msu.edu\n'>
# <re.Match object; span=(270, 292), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(195, 219), match=' jamkabila2001@yahoo.es\n'>
# <re.Match object; span=(103, 108), match=' R@M\n'>
# <re.Match object; span=(223, 270), match=' "webmaster@aclweb.org" <webmaster@aclweb.org>\n'>
# <re.Match object; span=(276, 294), match=' brownbag@citi.UM\n'>
# <re.Match object; span=(276, 295), match=' brown-bag@citi.UM\n'>
# <re.Match object; span=(233, 238), match=' R@M\n'>
# <re.Match object; span=(198, 203), match=' R@M\n'>
# <re.Match object; span=(287, 309), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(268, 290), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(104, 111), match=' <R@S>\n'>
# <re.Match object; span=(213, 218), match=' R@M\n'>
# <re.Match object; span=(157, 170), match=' "R@M" <R@M>\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(227, 251), match=' gabbagana@albawaba.com\n'>
# <re.Match object; span=(320, 353), match=' <salatu_ibru100@indiatimes.com>\n'>
# <re.Match object; span=(224, 229), match=' R@M\n'>
# <re.Match object; span=(168, 215), match=' "astrada@kukamail.com" <astrada@kukamail.com>\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(218, 223), match=' R@M\n'>
# <re.Match object; span=(224, 229), match=' R@M\n'>
# <re.Match object; span=(267, 298), match=' luisaastrada@portugalmail.com\n'>
# <re.Match object; span=(190, 195), match=' R@M\n'>
# <re.Match object; span=(482, 509), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(422, 448), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(201, 206), match=' R@M\n'>
# <re.Match object; span=(228, 250), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(265, 287), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(353, 373), match=' opetuy2k@yahoo.com\n'>
# <re.Match object; span=(278, 300), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(217, 222), match=' R@M\n'>
# <re.Match object; span=(182, 189), match=' <R@M>\n'>
# <re.Match object; span=(234, 256), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(501, 528), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(255, 276), match=' jamesoni2002@go.com\n'>
# <re.Match object; span=(255, 276), match=' jamesoni2002@go.com\n'>
# <re.Match object; span=(254, 275), match=' jamesoni2002@go.com\n'>
# <re.Match object; span=(279, 299), match=' engr_vict@shuf.com\n'>
# <re.Match object; span=(424, 450), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(218, 223), match=' R@M\n'>
# <re.Match object; span=(159, 164), match=' R@S\n'>
# <re.Match object; span=(180, 191), match=' si.all@UM\n'>
# <re.Match object; span=(283, 305), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(278, 300), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(186, 191), match=' R@M\n'>
# <re.Match object; span=(278, 300), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(301, 306), match=' R@M\n'>
# <re.Match object; span=(224, 246), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(218, 223), match=' R@M\n'>
# <re.Match object; span=(219, 224), match=' R@M\n'>
# <re.Match object; span=(274, 290), match=' smg@aber.ac.uk\n'>
# <re.Match object; span=(311, 316), match=' R@M\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(127, 132), match=' R@S\n'>
# <re.Match object; span=(162, 184), match=' mrsm_3sani@yahoo.com\n'>
# <re.Match object; span=(190, 195), match=' R@M\n'>
# <re.Match object; span=(221, 226), match=' R@M\n'>
# <re.Match object; span=(232, 259), match=' godfreyeche3@albawaba.com\n'>
# <re.Match object; span=(232, 259), match=' godfreyeche3@albawaba.com\n'>
# <re.Match object; span=(230, 235), match=' R@E\n'>
# <re.Match object; span=(274, 279), match=' R@E\n'>
# <re.Match object; span=(293, 315), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(250, 272), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(140, 165), match=' aminat_usman@fsmail.net\n'>
# <re.Match object; span=(220, 225), match=' R@M\n'>
# <re.Match object; span=(238, 243), match=' R@M\n'>
# <re.Match object; span=(211, 232), match=' ajahken@zwallet.com\n'>
# <re.Match object; span=(273, 296), match=' kampala09@zwallet.com\n'>
# <re.Match object; span=(334, 339), match=' R@M\n'>
# <re.Match object; span=(226, 231), match=' R@S\n'>
# <re.Match object; span=(352, 375), match=' wale_williams@post.cz\n'>
# <re.Match object; span=(365, 387), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(371, 393), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(187, 192), match=' R@M\n'>
# <re.Match object; span=(231, 258), match=' j_remitance@hknetmail.com\n'>
# <re.Match object; span=(319, 324), match=' R@M\n'>
# <re.Match object; span=(296, 301), match=' R@M\n'>
# <re.Match object; span=(319, 324), match=' R@E\n'>
# None
# <re.Match object; span=(209, 229), match=' godnkomo@yahoo.com\n'>
# <re.Match object; span=(208, 228), match=' godnkomo@yahoo.com\n'>
# <re.Match object; span=(381, 403), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(326, 348), match=' ab_nkomo@hotmail.com\n'>
# <re.Match object; span=(250, 267), match=' sseko019@go.com\n'>
# <re.Match object; span=(103, 128), match=' kennth_uman@zwallet.com\n'>
# <re.Match object; span=(104, 130), match=' pastor_faith@zwallet.com\n'>
# <re.Match object; span=(127, 132), match=' R@S\n'>
# <re.Match object; span=(262, 284), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(106, 132), match=' hammzaidiris@yahoo.co.uk\n'>
# <re.Match object; span=(127, 132), match=' R@S\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(367, 394), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(257, 279), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(163, 185), match=' jdrmoore@personal.ro\n'>
# <re.Match object; span=(299, 321), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(312, 334), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(275, 297), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(178, 183), match=' R@M\n'>
# <re.Match object; span=(203, 229), match=' joseph_zodwazd@yahoo.com\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(210, 215), match=' R@S\n'>
# <re.Match object; span=(184, 189), match=' R@M\n'>
# <re.Match object; span=(229, 234), match=' R@M\n'>
# <re.Match object; span=(192, 217), match=' fntbl@bigram.cs.jhu.edu\n'>
# <re.Match object; span=(64, 107), match=' "s.kaa@katamail.com" <s.kaa@katamail.com>\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(199, 204), match=' R@M\n'>
# <re.Match object; span=(198, 203), match=' R@M\n'>
# <re.Match object; span=(237, 259), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(180, 185), match=' R@M\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(368, 414), match=' =?iso-8859-1?Q?makathy?= <makathy@libero.it>\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(198, 203), match=' R@S\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(355, 375), match=' tikriti@arabia.com\n'>
# <re.Match object; span=(212, 217), match=' R@M\n'>
# <re.Match object; span=(165, 170), match=' R@M\n'>
# <re.Match object; span=(308, 330), match=' hk5000@flashmail.com\n'>
# <re.Match object; span=(215, 220), match=' R@M\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(276, 298), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(268, 290), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(207, 212), match=' R@M\n'>
# <re.Match object; span=(273, 293), match=' idrisumar94@go.com\n'>
# <re.Match object; span=(448, 468), match=' idrisumar94@go.com\n'>
# <re.Match object; span=(383, 403), match=' idrisumar94@go.com\n'>
# <re.Match object; span=(335, 359), match=' danbello07@hotmail.com\n'>
# <re.Match object; span=(569, 596), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(571, 598), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(365, 387), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(200, 205), match=' R@E\n'>
# <re.Match object; span=(230, 243), match=' Rrrrr <R@S>\n'>
# <re.Match object; span=(274, 287), match=' Rrrrr <R@E>\n'>
# <re.Match object; span=(230, 243), match=' Rrrrr <R@M>\n'>
# <re.Match object; span=(280, 304), match=' princeige@mail3000.com\n'>
# <re.Match object; span=(195, 202), match=' <R@M>\n'>
# <re.Match object; span=(250, 263), match=' Rrrrr <R@S>\n'>
# <re.Match object; span=(250, 263), match=' Rrrrr <R@E>\n'>
# <re.Match object; span=(250, 263), match=' Rrrrr <R@M>\n'>
# <re.Match object; span=(121, 150), match=' wgusers-outgoing@iwhome.com\n'>
# <re.Match object; span=(135, 152), match=' rademake@eml.cc\n'>
# None
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(215, 220), match=' R@M\n'>
# <re.Match object; span=(158, 163), match=' R@S\n'>
# <re.Match object; span=(171, 200), match=' wgusers-outgoing@iwhome.com\n'>
# <re.Match object; span=(158, 163), match=' R@S\n'>
# <re.Match object; span=(171, 200), match=' wgusers-outgoing@iwhome.com\n'>
# <re.Match object; span=(169, 174), match=' R@S\n'>
# <re.Match object; span=(301, 313), match=' jlawler@UM\n'>
# <re.Match object; span=(201, 206), match=' R@S\n'>
# <re.Match object; span=(351, 373), match=' ali_mohammed@123.com\n'>
# <re.Match object; span=(232, 237), match=' R@M\n'>
# <re.Match object; span=(376, 418), match=' <savimbicar1dogmail.co.uk@dogmail.co.uk>\n'>
# <re.Match object; span=(225, 249), match=' vumeh704@hknetmail.com\n'>
# <re.Match object; span=(170, 199), match=' wgusers-outgoing@iwhome.com\n'>
# <re.Match object; span=(322, 352), match=' mrslarrymann2003@yahoo.co.uk\n'>
# <re.Match object; span=(168, 188), match=' ken_dikko@yahoo.ca\n'>
# <re.Match object; span=(167, 212), match=' "SI2003@kukamail.com" <SI2003@kukamail.com>\n'>
# <re.Match object; span=(262, 284), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(153, 179), match=' akyari1@sudanmail.net.sd\n'>
# <re.Match object; span=(170, 211), match=' <llavanwa@UM>, <rossah@UM>, <jfine@UM>,\n'>
# <re.Match object; span=(232, 254), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(212, 217), match=' R@M\n'>
# <re.Match object; span=(151, 156), match=' R@S\n'>
# <re.Match object; span=(189, 194), match=' R@M\n'>
# <re.Match object; span=(182, 187), match=' R@M\n'>
# <re.Match object; span=(127, 151), match=' tambo_40@latinmail.com\n'>
# <re.Match object; span=(226, 231), match=' R@M\n'>
# <re.Match object; span=(225, 230), match=' R@M\n'>
# <re.Match object; span=(264, 286), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(206, 211), match=' R@M\n'>
# <re.Match object; span=(197, 202), match=' R@M\n'>
# None
# <re.Match object; span=(178, 183), match=' R@M\n'>
# <re.Match object; span=(181, 186), match=' R@M\n'>
# <re.Match object; span=(226, 231), match=' R@M\n'>
# <re.Match object; span=(113, 118), match=' R@M\n'>
# <re.Match object; span=(431, 457), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(285, 304), match=' kaluidikak@go.com\n'>
# <re.Match object; span=(195, 217), match=' makalele1@excite.com\n'>
# <re.Match object; span=(132, 156), match=' tambo_40@latinmail.com\n'>
# <re.Match object; span=(190, 212), match=' g_ineh@tiscali.co.uk\n'>
# <re.Match object; span=(247, 269), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(275, 297), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(276, 298), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(212, 217), match=' R@S\n'>
# <re.Match object; span=(253, 276), match=' engedetamanah@post.cz\n'>
# <re.Match object; span=(488, 515), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(203, 208), match=' R@M\n'>
# <re.Match object; span=(312, 332), match=' adew1@mail3000.com\n'>
# <re.Match object; span=(268, 288), match=' adew1@mail3000.com\n'>
# <re.Match object; span=(451, 477), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(285, 307), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(186, 191), match=' R@S\n'>
# <re.Match object; span=(169, 174), match=' R@S\n'>
# <re.Match object; span=(377, 401), match=' <mcabacha@freesurf.fr>\n'>
# <re.Match object; span=(584, 606), match=' PROSODY@list.msu.edu\n'>
# <re.Match object; span=(257, 262), match=' R@M\n'>
# <re.Match object; span=(117, 122), match=' R@S\n'>
# <re.Match object; span=(305, 330), match=' <ifeanyi_uzo@yahoo.com>\n'>
# <re.Match object; span=(202, 218), match=' modey06@go.com\n'>
# <re.Match object; span=(166, 171), match=' R@S\n'>
# <re.Match object; span=(262, 284), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(324, 351), match=' <2003vincent@freesurf.fr>\n'>
# <re.Match object; span=(268, 290), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(290, 317), match=' <jerrypeter2@freesurf.fr>\n'>
# <re.Match object; span=(211, 232), match=' mnoah12@hotmail.com\n'>
# <re.Match object; span=(191, 196), match=' R@E\n'>
# <re.Match object; span=(233, 255), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(109, 114), match=' R@S\n'>
# <re.Match object; span=(254, 276), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(121, 126), match=' R@S\n'>
# <re.Match object; span=(388, 415), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(388, 415), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(164, 191), match=' <info-www-search@ISI.EDU>\n'>
# <re.Match object; span=(315, 334), match=' dtshombe2@123.com\n'>
# <re.Match object; span=(243, 265), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(112, 117), match=' R@E\n'>
# <re.Match object; span=(242, 264), match=' frankokonjo5@123.com\n'>
# <re.Match object; span=(278, 300), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(243, 265), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(471, 493), match=' PROSODY@list.msu.edu\n'>
# <re.Match object; span=(251, 278), match=' rf@inter-disciplinary.net\n'>
# <re.Match object; span=(209, 236), match=' revcistercium@planafla.es\n'>
# <re.Match object; span=(328, 349), match=' mary_abass2@123.com\n'>
# <re.Match object; span=(242, 264), match=' frankokonjo6@123.com\n'>
# <re.Match object; span=(219, 242), match=' vinokoni5@hotmail.com\n'>
# <re.Match object; span=(181, 186), match=' R@S\n'>
# <re.Match object; span=(203, 208), match=' R@E\n'>
# <re.Match object; span=(281, 300), match=' dtshombe3@123.com\n'>
# <re.Match object; span=(216, 237), match=' mark5_2003@mail.com\n'>
# <re.Match object; span=(225, 230), match=' R@M\n'>
# <re.Match object; span=(320, 335), match=' elosuba@o2.pl\n'>
# <re.Match object; span=(227, 253), match=' <yetunde@mail2world.com>\n'>
# <re.Match object; span=(227, 253), match=' <yetunde@mail2world.com>\n'>
# <re.Match object; span=(128, 155), match=' lary_kamokai1@hotmail.com\n'>
# <re.Match object; span=(233, 238), match=' R@M\n'>
# <re.Match object; span=(386, 410), match=' <fredkuma@freesurf.fr>\n'>
# <re.Match object; span=(186, 191), match=' R@M\n'>
# <re.Match object; span=(510, 536), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(218, 223), match=' R@M\n'>
# <re.Match object; span=(168, 173), match=' R@S\n'>
# <re.Match object; span=(388, 415), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(190, 195), match=' R@M\n'>
# <re.Match object; span=(217, 222), match=' R@M\n'>
# <re.Match object; span=(202, 230), match=' jidewilliams000@arabia.com\n'>
# <re.Match object; span=(66, 88), match=' ta_mete@katamail.com\n'>
# <re.Match object; span=(107, 128), match=' r_weis@mailcity.com\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(137, 142), match=' R@S\n'>
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(204, 209), match=' R@M\n'>
# <re.Match object; span=(203, 208), match=' R@M\n'>
# <re.Match object; span=(552, 578), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(141, 167), match=' abamohammed@ananzi.co.za\n'>
# <re.Match object; span=(210, 215), match=' R@M\n'>
# <re.Match object; span=(219, 224), match=' R@M\n'>
# <re.Match object; span=(220, 225), match=' R@S\n'>
# <re.Match object; span=(207, 212), match=' R@M\n'>
# <re.Match object; span=(225, 230), match=' R@M\n'>
# <re.Match object; span=(68, 119), match=' "zainabuba@katamail.com" <zainabuba@katamail.com>
# <re.Match object; span=(424, 450), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(534, 560), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(236, 241), match=' R@S\n'>
# <re.Match object; span=(178, 183), match=' R@S\n'>
# <re.Match object; span=(239, 244), match=' R@M\n'>
# <re.Match object; span=(239, 244), match=' R@M\n'>
# <re.Match object; span=(183, 188), match=' R@M\n'>
# <re.Match object; span=(158, 180), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(284, 303), match=' brown-bag@citi.UM\n'>
# <re.Match object; span=(198, 203), match=' R@M\n'>
# <re.Match object; span=(221, 226), match=' R@M\n'>
# <re.Match object; span=(195, 217), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(195, 217), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(202, 224), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(224, 243), match=' brown-bag@citi.UM\n'>
# <re.Match object; span=(324, 368), match=' "patelnikes4you" <patelnikes4you@yahoo.ca>\n'>
# <re.Match object; span=(326, 370), match=' "patelnikes4you" <patelnikes4you@yahoo.ca>\n'>
# <re.Match object; span=(326, 370), match=' "patelnikes4you" <patelnikes4you@yahoo.ca>\n'>
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(180, 182), match=' \n'>
# <re.Match object; span=(191, 223), match=' selina_gabrielmarinze@voila.fr\n'>
# <re.Match object; span=(254, 274), match=' project101@123.com\n'>
# <re.Match object; span=(235, 240), match=' R@M\n'>
# <re.Match object; span=(105, 132), match=' kolajohnsons1@zwallet.com\n'>
# <re.Match object; span=(244, 264), match=' mrs_susan2@123.com\n'>
# <re.Match object; span=(219, 241), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(171, 193), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(248, 268), match=' kendikko01@123.com\n'>
# <re.Match object; span=(422, 449), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(169, 191), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(166, 188), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(161, 183), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(196, 201), match=' R@S\n'>
# <re.Match object; span=(197, 202), match=' R@M\n'>
# <re.Match object; span=(114, 138), match=' jonbwaya@tiscali.co.uk\n'>
# <re.Match object; span=(114, 138), match=' jonbwaya@tiscali.co.uk\n'>
# <re.Match object; span=(257, 282), match=' williamisiaka55@123.com\n'>
# <re.Match object; span=(172, 199), match=' david50mapuka@yahoo.co.in\n'>
# <re.Match object; span=(230, 235), match=' R@M\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(212, 217), match=' R@M\n'>
# <re.Match object; span=(147, 177), match=' errol_marshall2@albawaba.com\n'>
# <re.Match object; span=(260, 292), match=' mrsjaneabdullah@123.123mail.cl\n'>
# <re.Match object; span=(264, 284), match=' yet_bassey@123.com\n'>
# <re.Match object; span=(238, 243), match=' R@M\n'>
# <re.Match object; span=(240, 245), match=' R@M\n'>
# <re.Match object; span=(217, 222), match=' R@M\n'>
# <re.Match object; span=(237, 242), match=' R@S\n'>
# <re.Match object; span=(240, 245), match=' R@M\n'>
# <re.Match object; span=(210, 215), match=' R@S\n'>
# <re.Match object; span=(359, 383), match=' mallam_65@weedmail.com\n'>
# <re.Match object; span=(476, 502), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(469, 495), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(474, 501), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(180, 201), match=' sogolo_hmd@juno.com\n'>
# <re.Match object; span=(172, 177), match=' R@M\n'>
# <re.Match object; span=(195, 200), match=' R@M\n'>
# <re.Match object; span=(185, 190), match=' R@M\n'>
# <re.Match object; span=(192, 197), match=' R@M\n'>
# <re.Match object; span=(152, 157), match=' R@S\n'>
# <re.Match object; span=(213, 218), match=' R@M\n'>
# <re.Match object; span=(117, 142), match=' jeffmboma@tiscali.co.uk\n'>
# <re.Match object; span=(214, 236), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(166, 192), match=' idrismusasa2@yahoo.co.in\n'>
# <re.Match object; span=(233, 250), match=' dukenze@123.com\n'>
# <re.Match object; span=(233, 250), match=' dukenze@123.com\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(181, 186), match=' R@M\n'>
# <re.Match object; span=(196, 218), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(237, 254), match=' mmssko2@123.com\n'>
# <re.Match object; span=(231, 253), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(209, 214), match=' R@M\n'>
# <re.Match object; span=(203, 208), match=' R@S\n'>
# <re.Match object; span=(122, 127), match=' R@M\n'>
# <re.Match object; span=(199, 221), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(180, 197), match=' dada@fsmail.net\n'>
# <re.Match object; span=(264, 284), match=' yet_bassey@123.com\n'>
# <re.Match object; span=(266, 289), match=' susanshubangu@123.com\n'>
# <re.Match object; span=(213, 239), match=' kayodephillip@fsmail.net\n'>
# <re.Match object; span=(123, 128), match=' R@S\n'>
# <re.Match object; span=(161, 168), match=' <R@M>\n'>
# <re.Match object; span=(98, 105), match=' <R@S>\n'>
# <re.Match object; span=(161, 168), match=' <R@M>\n'>
# <re.Match object; span=(156, 163), match=' <R@S>\n'>
# <re.Match object; span=(324, 341), match=' alex@afadia.com\n'>
# <re.Match object; span=(195, 200), match=' R@M\n'>
# <re.Match object; span=(293, 338), match=' JOHN1@fate.mr.itd.UM, YORMIE@fate.mr.itd.UM\n'>
# <re.Match object; span=(270, 292), match=' mallam_bello@123.com\n'>
# <re.Match object; span=(205, 229), match=' jamesmorgan@fsmail.net\n'>
# <re.Match object; span=(339, 364), match=' fntbl@bigram.cs.jhu.edu\n'>
# <re.Match object; span=(336, 361), match=' fntbl@bigram.cs.jhu.edu\n'>
# <re.Match object; span=(327, 332), match=' R@M\n'>
# <re.Match object; span=(342, 364), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(178, 203), match=' bluemariam@katamail.com\n'>
# <re.Match object; span=(313, 335), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(280, 300), match=' fbello@megamail.pt\n'>
# <re.Match object; span=(278, 298), match=' fbello@megamail.pt\n'>
# <re.Match object; span=(221, 226), match=' R@M\n'>
# <re.Match object; span=(248, 270), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(247, 252), match=' R@M\n'>
# <re.Match object; span=(194, 199), match=' R@M\n'>
# <re.Match object; span=(225, 230), match=' R@M\n'>
# <re.Match object; span=(231, 260), match=' abachafamily4@tiscali.co.uk\n'>
# <re.Match object; span=(75, 104), match=' randall36@goldengoofball.us\n'>
# <re.Match object; span=(258, 263), match=' R@S\n'>
# <re.Match object; span=(186, 205), match=' kojadams@voila.fr\n'>
# <re.Match object; span=(204, 209), match=' R@M\n'>
# <re.Match object; span=(222, 244), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(208, 213), match=' R@M\n'>
# <re.Match object; span=(323, 354), match=' "mjaja02" <mjaja02@libero.it>\n'>
# <re.Match object; span=(216, 238), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(217, 222), match=' R@M\n'>
# <re.Match object; span=(246, 268), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(158, 163), match=' R@S\n'>
# <re.Match object; span=(215, 220), match=' R@M\n'>
# <re.Match object; span=(231, 257), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(202, 225), match=' hc_agah555@fsmail.net\n'>
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(468, 494), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(451, 477), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(198, 203), match=' R@M\n'>
# <re.Match object; span=(206, 211), match=' R@M\n'>
# <re.Match object; span=(145, 150), match=' R@S\n'>
# <re.Match object; span=(193, 215), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(229, 250), match=' bg-ling-owner@si.UM\n'>
# <re.Match object; span=(241, 263), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(170, 175), match=' R@S\n'>
# <re.Match object; span=(226, 231), match=' R@S\n'>
# <re.Match object; span=(236, 258), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(236, 258), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(215, 241), match=' gregorykabila333@mail.bg\n'>
# <re.Match object; span=(302, 326), match=' maryalade66@fsmail.net\n'>
# <re.Match object; span=(193, 198), match=' R@S\n'>
# <re.Match object; span=(228, 233), match=' R@M\n'>
# <re.Match object; span=(201, 223), match=' ka_hammed@fsmail.net\n'>
# <re.Match object; span=(203, 226), match=' mar_maryam@fsmail.net\n'>
# <re.Match object; span=(196, 201), match=' R@M\n'>
# <re.Match object; span=(137, 166), match=' mohameed_aba1@tiscali.co.uk\n'>
# <re.Match object; span=(135, 163), match=' mohameed_aba@tiscali.co.uk\n'>
# <re.Match object; span=(244, 262), match=' george2000@wp.pl\n'>
# <re.Match object; span=(178, 183), match=' R@M\n'>
# <re.Match object; span=(156, 184), match=' mohameed_aba@tiscali.co.uk\n'>
# <re.Match object; span=(161, 166), match=' R@S\n'>
# <re.Match object; span=(247, 252), match=' R@M\n'>
# <re.Match object; span=(134, 158), match=' kufor2000@tatanova.com\n'>
# <re.Match object; span=(146, 176), match=' matthewmolefe3@webmail.co.za\n'>
# <re.Match object; span=(194, 215), match=' ebaye52@yahoo.co.uk\n'>
# <re.Match object; span=(186, 205), match=' tblmichl@voila.fr\n'>
# <re.Match object; span=(213, 239), match=' dr_usmanbello@fsmail.net\n'>
# <re.Match object; span=(325, 330), match=' R@M\n'>
# <re.Match object; span=(142, 166), match=' 03mariam@tiscali.co.uk\n'>
# <re.Match object; span=(217, 245), match=' jeweltaylor_274@fsmail.net\n'>
# <re.Match object; span=(232, 254), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(221, 226), match=' R@M\n'>
# <re.Match object; span=(194, 216), match=' rws@research.att.com\n'>
# <re.Match object; span=(218, 223), match=' R@E\n'>
# <re.Match object; span=(262, 267), match=' R@E\n'>
# <re.Match object; span=(183, 188), match=' R@M\n'>
# <re.Match object; span=(227, 232), match=' R@M\n'>
# <re.Match object; span=(191, 211), match=' bmusa11@fsmail.net\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(160, 181), match=' mikeigbol@yahoo.com\n'>
# <re.Match object; span=(233, 238), match=' R@M\n'>
# <re.Match object; span=(674, 700), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(225, 251), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(225, 251), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(207, 212), match=' R@M\n'>
# <re.Match object; span=(145, 169), match=' roseoba1@webmail.co.za\n'>
# <re.Match object; span=(228, 252), match=' jj_walter9@netzero.com\n'>
# <re.Match object; span=(126, 150), match=' rader_rick@hotmail.com\n'>
# <re.Match object; span=(178, 183), match=' R@M\n'>
# <re.Match object; span=(253, 258), match=' R@E\n'>
# <re.Match object; span=(167, 172), match=' R@M\n'>
# None
# <re.Match object; span=(195, 215), match=' jubeegv@fsmail.net\n'>
# <re.Match object; span=(213, 240), match=' dr_kanuchijuka@fsmail.net\n'>
# <re.Match object; span=(154, 183), match=' jordanhamson112003@yahoo.fr\n'>
# <re.Match object; span=(172, 177), match=' R@S\n'>
# <re.Match object; span=(172, 177), match=' R@S\n'>
# <re.Match object; span=(229, 234), match=' R@M\n'>
# <re.Match object; span=(232, 258), match=' nkomo2004_026@fsmail.net\n'>
# <re.Match object; span=(275, 301), match=' nkomo2004_026@fsmail.net\n'>
# <re.Match object; span=(377, 403), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(134, 139), match=' R@S\n'>
# <re.Match object; span=(193, 198), match=' R@M\n'>
# <re.Match object; span=(212, 238), match=' patrickatike2@fsmail.net\n'>
# <re.Match object; span=(190, 210), match=' nze_moore@voila.fr\n'>
# <re.Match object; span=(386, 413), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(214, 239), match=' engrtonyedem@fsmail.net\n'>
# <re.Match object; span=(214, 239), match=' engrtonyedem@fsmail.net\n'>
# <re.Match object; span=(136, 161), match=' kufor_1000@tatanova.com\n'>
# <re.Match object; span=(199, 204), match=' R@S\n'>
# <re.Match object; span=(219, 224), match=' R@E\n'>
# <re.Match object; span=(180, 185), match=' R@E\n'>
# <re.Match object; span=(224, 229), match=' R@E\n'>
# <re.Match object; span=(247, 269), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(387, 414), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(238, 260), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(203, 225), match=' barrisolu@fsmail.net\n'>
# <re.Match object; span=(139, 167), match=' frankdamas34@webmail.co.za\n'>
# <re.Match object; span=(455, 481), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(460, 486), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(238, 249), match=' paubel@UM\n'>
# <re.Match object; span=(245, 267), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(186, 205), match=' ohams1@fsmail.net\n'>
# <re.Match object; span=(222, 227), match=' R@M\n'>
# <re.Match object; span=(204, 228), match=' paul147_422@fsmail.net\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(197, 218), match=' mrramatu@fsmail.net\n'>
# <re.Match object; span=(303, 316), match=' pwjensen@UM\n'>
# <re.Match object; span=(189, 207), match=' h00o17@yahoo.com\n'>
# <re.Match object; span=(178, 200), match=' nkomo_2004@cosmo.com\n'>
# <re.Match object; span=(222, 244), match=' nkomo_2004@cosmo.com\n'>
# <re.Match object; span=(217, 235), match=' fntbl@cs.jhu.edu\n'>
# <re.Match object; span=(164, 186), match=' ike_oba1@yahoo.co.uk\n'>
# <re.Match object; span=(248, 270), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(219, 237), match=' fntbl@cs.jhu.edu\n'>
# <re.Match object; span=(223, 228), match=' R@M\n'>
# <re.Match object; span=(216, 221), match=' R@S\n'>
# <re.Match object; span=(223, 228), match=' R@M\n'>
# None
# <re.Match object; span=(308, 336), match=' martinsaku01@truthmail.com\n'>
# <re.Match object; span=(308, 336), match=' martinsaku01@truthmail.com\n'>
# <re.Match object; span=(247, 252), match=' R@E\n'>
# <re.Match object; span=(203, 208), match=' R@E\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(202, 225), match=' ahmedabu@e-tapaal.com\n'>
# <re.Match object; span=(165, 170), match=' R@M\n'>
# <re.Match object; span=(211, 216), match=' R@M\n'>
# <re.Match object; span=(203, 208), match=' R@M\n'>
# None
# <re.Match object; span=(141, 168), match=' mzimba_vivian@hotmail.com\n'>
# <re.Match object; span=(210, 232), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(215, 220), match=' R@M\n'>
# <re.Match object; span=(201, 223), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(190, 212), match=' ramatemail@cosmo.com\n'>
# <re.Match object; span=(234, 256), match=' ramatemail@cosmo.com\n'>
# <re.Match object; span=(186, 205), match=' larryacb@voila.fr\n'>
# <re.Match object; span=(186, 205), match=' larryacb@voila.fr\n'>
# <re.Match object; span=(242, 247), match=' R@M\n'>
# <re.Match object; span=(223, 228), match=' R@S\n'>
# <re.Match object; span=(376, 400), match=' dudu1234@webmail.co.za\n'>
# <re.Match object; span=(93, 100), match=' <R@S>\n'>
# <re.Match object; span=(195, 200), match=' R@M\n'>
# <re.Match object; span=(380, 406), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(172, 194), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(166, 191), match=' richardakueze@cosmo.com\n'>
# <re.Match object; span=(236, 241), match=' R@M\n'>
# <re.Match object; span=(232, 237), match=' R@M\n'>
# <re.Match object; span=(331, 372), match=' "jeffersila04" <jeffersila04@libero.it>\n'>
# <re.Match object; span=(183, 188), match=' R@M\n'>
# <re.Match object; span=(165, 187), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(277, 296), match=' gt2002@fsmail.net\n'>
# <re.Match object; span=(159, 181), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(201, 222), match=' icos3@ags.uni-sb.de\n'>
# <re.Match object; span=(203, 208), match=' R@M\n'>
# <re.Match object; span=(209, 214), match=' R@M\n'>
# <re.Match object; span=(203, 208), match=' R@S\n'>
# <re.Match object; span=(203, 208), match=' R@S\n'>
# <re.Match object; span=(204, 209), match=' R@M\n'>
# <re.Match object; span=(214, 219), match=' R@M\n'>
# <re.Match object; span=(166, 171), match=' R@M\n'>
# <re.Match object; span=(192, 197), match=' R@M\n'>
# <re.Match object; span=(217, 222), match=' R@S\n'>
# <re.Match object; span=(216, 221), match=' R@M\n'>
# <re.Match object; span=(203, 208), match=' R@M\n'>
# <re.Match object; span=(199, 204), match=' R@M\n'>
# <re.Match object; span=(111, 133), match=' mariam_9999@atlas.cz\n'>
# <re.Match object; span=(185, 204), match=' abacha80@voila.fr\n'>
# <re.Match object; span=(167, 193), match=' tonyoba32001@yahoo.co.uk\n'>
# <re.Match object; span=(167, 193), match=' tonyoba32001@yahoo.co.uk\n'>
# <re.Match object; span=(395, 418), match=' wwwsolomon@mail.co.za\n'>
# <re.Match object; span=(375, 403), match=' sekomariam2001@telstra.com\n'>
# <re.Match object; span=(157, 179), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(302, 323), match=' belsa@acazamail.com\n'>
# <re.Match object; span=(190, 214), match=' eholtz@fas.harvard.edu\n'>
# <re.Match object; span=(156, 178), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(158, 180), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(341, 413), match=' pxu2@jhem.jhu.edu, och@isi.edu, fraser@isi.edu, >
# <re.Match object; span=(271, 290), match=' psaaiman2@mail.az\n'>
# <re.Match object; span=(158, 163), match=' R@S\n'>
# <re.Match object; span=(171, 194), match=' johnobi@glomamail.com\n'>
# <re.Match object; span=(293, 298), match=' R@M\n'>
# <re.Match object; span=(353, 371), match=' sadmarah@sapo.pt\n'>
# <re.Match object; span=(354, 372), match=' sadmarah@sapo.pt\n'>
# <re.Match object; span=(327, 332), match=' R@M\n'>
# <re.Match object; span=(355, 360), match=' R@M\n'>
# <re.Match object; span=(261, 266), match=' R@S\n'>
# <re.Match object; span=(289, 320), match=' williamsghazi2002@yahoo.co.in\n'>
# None
# <re.Match object; span=(563, 590), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(282, 304), match=' starrast@yahoo.co.uk\n'>
# None
# <re.Match object; span=(121, 143), match=' webmaster@aclweb.org\n'>
# None
# <re.Match object; span=(205, 210), match=' R@M\n'>
# <re.Match object; span=(169, 194), match=' jerryahmedjr@fsmail.net\n'>
# <re.Match object; span=(167, 189), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(390, 427), match=' nutch-general@lists.sourceforge.net\n'>
# None
# <re.Match object; span=(176, 181), match=' R@M\n'>
# <re.Match object; span=(330, 367), match=' "dr_frances" <dr_frances@libero.it>\n'>
# <re.Match object; span=(330, 367), match=' "dr_frances" <dr_frances@libero.it>\n'>
# <re.Match object; span=(206, 211), match=' R@M\n'>
# <re.Match object; span=(206, 224), match=' moloco5@yahoo.ca\n'>
# <re.Match object; span=(410, 437), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(410, 437), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(267, 286), match=' jobulu1@torba.com\n'>
# <re.Match object; span=(311, 330), match=' jobulu1@torba.com\n'>
# <re.Match object; span=(198, 223), match=' alicekobe@emailclue.com\n'>
# <re.Match object; span=(198, 223), match=' alicekobe@emailclue.com\n'>
# <re.Match object; span=(198, 223), match=' alicekobe@emailclue.com\n'>
# <re.Match object; span=(175, 197), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(273, 297), match=' dpatrick88@telstra.com\n'>
# <re.Match object; span=(317, 341), match=' dpatrick88@telstra.com\n'>
# <re.Match object; span=(273, 297), match=' dpatrick88@telstra.com\n'>
# <re.Match object; span=(236, 259), match=' klugman_002@yahoo.com\n'>
# <re.Match object; span=(293, 319), match=' richardshub011@yahoo.com\n'>
# <re.Match object; span=(251, 273), match=' kamasutu@telstra.com\n'>
# <re.Match object; span=(287, 308), match=' dr_tta1@hotmail.com\n'>
# <re.Match object; span=(218, 223), match=' R@M\n'>
# <re.Match object; span=(346, 366), match=' nzani3@telstra.com\n'>
# <re.Match object; span=(269, 292), match=' iusmanng2@telstra.com\n'>
# <re.Match object; span=(118, 137), match=' cyril8@telkom.net\n'>
# <re.Match object; span=(215, 220), match=' R@M\n'>
# <re.Match object; span=(264, 285), match=' james001@postino.it\n'>
# <re.Match object; span=(204, 209), match=' R@M\n'>
# <re.Match object; span=(171, 193), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(222, 227), match=' R@M\n'>
# <re.Match object; span=(215, 220), match=' R@S\n'>
# <re.Match object; span=(169, 191), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(313, 335), match=' jamesnandu11@mac.com\n'>
# <re.Match object; span=(302, 307), match=' R@M\n'>
# <re.Match object; span=(294, 299), match=' R@S\n'>
# <re.Match object; span=(150, 172), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(203, 208), match=' R@S\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# <re.Match object; span=(242, 281), match=' philipajayi_lawfirm@lawoffice2004.com\n'>
# <re.Match object; span=(200, 205), match=' R@M\n'>
# ...
# None
# None
# <re.Match object; span=(138, 143), match=' R@M\n'>
# <re.Match object; span=(199, 204), match=' R@M\n'>
# <re.Match object; span=(609, 636), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(614, 641), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(601, 628), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(224, 229), match=' R@S\n'>
# <re.Match object; span=(590, 617), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(595, 622), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(397, 416), match=' <info@parker.com>\n'>
# <re.Match object; span=(97, 102), match=' R@M\n'>
# <re.Match object; span=(598, 622), match=' nico_audit@yahoo.co.uk\n'>
# <re.Match object; span=(397, 424), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(571, 598), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(138, 143), match=' R@S\n'>
# None
# <re.Match object; span=(563, 590), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(413, 448), match=' rebecca_david20002001@yahoo.co.jp\n'>
# None
# None
# <re.Match object; span=(745, 771), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(538, 565), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(416, 440), match=' <mrrmaria@socorro.com>\n'>
# <re.Match object; span=(416, 440), match=' <mrrmaria@socorro.com>\n'>
# None
# None
# <re.Match object; span=(263, 290), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(136, 141), match=' R@M\n'>
# None
# <re.Match object; span=(557, 584), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(263, 290), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(556, 583), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(134, 141), match=' <R@M>\n'>
# <re.Match object; span=(257, 297), match=' <kennethcolemailcom@thestudentzon.com>\n'>
# <re.Match object; span=(104, 109), match=' R@S\n'>
# <re.Match object; span=(209, 236), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(569, 596), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(553, 580), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(569, 596), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(117, 132), match=' "rrrrr" <R@S>\n'>
# None
# None
# <re.Match object; span=(308, 315), match=' <R@S>\n'>
# <re.Match object; span=(192, 197), match=' R@S\n'>
# <re.Match object; span=(192, 197), match=' R@M\n'>
# <re.Match object; span=(249, 314), match=' "saku_watara2007@latinmail.com" <saku_watara2007>
# None
# <re.Match object; span=(183, 188), match=' R@M\n'>
# <re.Match object; span=(560, 581), match=' pslagents@yahoo.com\n'>
# <re.Match object; span=(560, 581), match=' pslagents@yahoo.com\n'>
# <re.Match object; span=(566, 585), match=' radityo@yahoo.com\n'>
# <re.Match object; span=(178, 185), match=' <R@S>\n'>
# None
# <re.Match object; span=(449, 478), match=' mr_andyhornby51@yahoo.co.jp\n'>
# <re.Match object; span=(407, 433), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(352, 379), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(265, 283), match=' muspham@email.si\n'>
# <re.Match object; span=(350, 377), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(350, 377), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(585, 612), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(311, 318), match=' <R@M>\n'>
# <re.Match object; span=(554, 576), match=' amd_muzazah@yahoo.fr\n'>
# <re.Match object; span=(303, 326), match=' "Rachael Oniga" <R@S>\n'>
# None
# <re.Match object; span=(716, 743), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(1059, 1086), match=' undisclosed-recipients: ;\n'>
# None
# None
# None
# None
# None
# <re.Match object; span=(166, 194), match=' gloria_zuma002@yahoo.co.in\n'>
# None
# <re.Match object; span=(3171, 3198), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(403, 417), match=' <olssonk@UM>\n'>
# <re.Match object; span=(160, 185), match=' kubafamily001@yahoo.com\n'>
# None
# <re.Match object; span=(489, 516), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(194, 220), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(564, 587), match=' sussanbien44@yahoo.ca\n'>
# <re.Match object; span=(557, 580), match=' sussanbien11@yahoo.ca\n'>
# <re.Match object; span=(660, 683), match=' naomi_stphae@yahoo.it\n'>
# None
# <re.Match object; span=(473, 500), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(321, 346), match=' <shoulson@cs.CU>, <R@C>\n'>
# <re.Match object; span=(593, 620), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(221, 249), match=' ab.marinho8@zipmail.com.br\n'>
# <re.Match object; span=(162, 188), match=' lmnandi02@pnetmail.co.za\n'>
# None
# <re.Match object; span=(185, 202), match=' sarba@sarba.com\n'>
# <re.Match object; span=(185, 202), match=' sarba@sarba.com\n'>
# None
# <re.Match object; span=(523, 552), match=' godwin_johnson1986@yahoo.fr\n'>
# <re.Match object; span=(574, 601), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(220, 225), match=' R@M\n'>
# None
# <re.Match object; span=(862, 889), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(1112, 1138), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(173, 175), match=' \n'>
# <re.Match object; span=(207, 226), match=' ip@v2.listbox.com\n'>
# <re.Match object; span=(449, 476), match=' anita03_adams@yahoo.co.jp\n'>
# <re.Match object; span=(272, 295), match=' <martins@ab-sa.co.za>\n'>
# <re.Match object; span=(533, 543), match=' rsami@UM\n'>
# None
# <re.Match object; span=(329, 350), match=' <helen@ab-sa.co.za>\n'>
# <re.Match object; span=(609, 636), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(242, 268), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(176, 198), match=' g.ajithkumar@msn.com\n'>
# <re.Match object; span=(473, 500), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(252, 319), match=' "mr_hassanbilly01@latinmail.com" <mr_hassanbilly>
# <re.Match object; span=(536, 563), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(146, 151), match=' R@S\n'>
# None
# None
# <re.Match object; span=(828, 854), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(431, 438), match=' <R@S>\n'>
# <re.Match object; span=(273, 300), match=' <overlobe@ozemail.com.au>\n'>
# <re.Match object; span=(200, 205), match=' R@C\n'>
# <re.Match object; span=(277, 304), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(160, 185), match=' nelsonsmith033@terra.es\n'>
# <re.Match object; span=(335, 358), match=' <info@bebemous.co.za>\n'>
# <re.Match object; span=(990, 1016), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(785, 812), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(1221, 1247), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(1218, 1244), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(1025, 1051), match=' undisclosed-recipients:;\n'>
# None
# None
# <re.Match object; span=(279, 284), match=' R@C\n'>
# None
# <re.Match object; span=(310, 328), match=' uchefx@yahoo.com\n'>
# None
# None
# <re.Match object; span=(328, 354), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(941, 967), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(486, 515), match=' mrcolinshand20@poczta.pf.pl\n'>
# None
# None
# None
# None
# <re.Match object; span=(184, 189), match=' R@M\n'>
# None
# None
# <re.Match object; span=(495, 522), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(592, 619), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(499, 526), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(435, 442), match=' <R@S>\n'>
# <re.Match object; span=(260, 281), match=' <jones@ab-sa.co.za>\n'>
# <re.Match object; span=(125, 130), match=' R@S\n'>
# <re.Match object; span=(590, 616), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(318, 325), match=' <R@S>\n'>
# <re.Match object; span=(470, 481), match=' you@cs.CU\n'>
# <re.Match object; span=(977, 1011), match=' mikegillsforremmittance@yahoo.de\n'>
# <re.Match object; span=(263, 290), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(234, 258), match=' alimoheamed1@mynet.com\n'>
# <re.Match object; span=(494, 520), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(390, 417), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(507, 528), match=' cheralie01@yahoo.fr\n'>
# None
# <re.Match object; span=(481, 508), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(489, 516), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(193, 208), match=' "rrrrr" <R@M>\n'>
# <re.Match object; span=(141, 157), match=' N/A <>, N/A <>\n'>
# <re.Match object; span=(1136, 1163), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(263, 268), match=' R@M\n'>
# <re.Match object; span=(995, 1022), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(141, 149), match=' N/A <>\n'>
# None
# <re.Match object; span=(717, 739), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(557, 583), match=' undisclosed-recipients:;\n'>
# None
# None
# None
# None
# None
# <re.Match object; span=(265, 291), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(396, 422), match=' rose_kouakou002@yahoo.fr\n'>
# <re.Match object; span=(633, 663), match=' solomonclarkeclarke@yahoo.co\n'>
# <re.Match object; span=(206, 233), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(206, 232), match=' undisclosed-recipients:;\n'>
# None
# None
# <re.Match object; span=(574, 598), match=' inusjohn15@yahoo.co.in\n'>
# None
# None
# None
# <re.Match object; span=(375, 401), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(418, 439), match=' pre91@pre.sltnet.lk\n'>
# <re.Match object; span=(668, 695), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(536, 562), match=' undisclosed-recipients:;\n'>
# None
# None
# <re.Match object; span=(751, 778), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(523, 546), match=' saintarmanda@yahoo.fr\n'>
# <re.Match object; span=(838, 865), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(870, 896), match=' undisclosed-recipients:;\n'>
# None
# None
# <re.Match object; span=(384, 410), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(491, 514), match=' saintarmanda@yahoo.fr\n'>
# <re.Match object; span=(394, 421), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(379, 405), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(181, 218), match=' "Dear Sir" <kimati.didan@gmail.com>\n'>
# None
# <re.Match object; span=(310, 336), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(209, 228), match=' dyorke@freenet.de\n'>
# <re.Match object; span=(331, 359), match=' bg-comp-owner@krusty.si.UM\n'>
# <re.Match object; span=(343, 375), match=' bg-announce-owner@krusty.si.UM\n'>
# <re.Match object; span=(315, 320), match=' R@S\n'>
# None
# None
# None
# <re.Match object; span=(135, 140), match=' R@S\n'>
# <re.Match object; span=(662, 689), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(401, 426), match=' mariamgueie@yahoo.co.jp\n'>
# <re.Match object; span=(344, 366), match=' secretary@aclweb.org\n'>
# <re.Match object; span=(343, 365), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(286, 309), match=' febregasagent@aim.com\n'>
# <re.Match object; span=(382, 408), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(293, 295), match=' \n'>
# None
# <re.Match object; span=(662, 684), match=' secretary@aclweb.org\n'>
# <re.Match object; span=(505, 510), match=' R@M\n'>
# None
# <re.Match object; span=(378, 433), match=' unlisted-recipients:; (no To-header on input)@ma>
# None
# <re.Match object; span=(755, 782), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(543, 548), match=' R@M\n'>
# <re.Match object; span=(543, 548), match=' R@S\n'>
# <re.Match object; span=(559, 586), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(344, 362), match=' info@atheros.com\n'>
# <re.Match object; span=(497, 524), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(758, 784), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(412, 438), match=' <jen_marthin01@yahoo.fr>\n'>
# <re.Match object; span=(454, 496), match=' rafraser@mechoffice.watstar.uwaterloo.ca\n'>
# <re.Match object; span=(454, 496), match=' rafraser@mechoffice.watstar.uwaterloo.ca\n'>
# None
# None
# <re.Match object; span=(178, 183), match=' R@S\n'>
# <re.Match object; span=(505, 532), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(233, 280), match=' "bajoga@latinmail.com" <bajoga@latinmail.com>\n'>
# <re.Match object; span=(389, 409), match=' rubzuul@freenet.de\n'>
# <re.Match object; span=(179, 184), match=' R@S\n'>
# <re.Match object; span=(772, 799), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(772, 799), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(495, 522), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(136, 141), match=' R@C\n'>
# <re.Match object; span=(245, 300), match=' "gosolanges@latinmail.com" <gosolanges@latinmail>
# None
# <re.Match object; span=(501, 528), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(501, 528), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(395, 423), match=' sarat_hassan12000@yahoo.jp\n'>
# <re.Match object; span=(139, 144), match=' R@M\n'>
# <re.Match object; span=(160, 186), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(281, 307), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(415, 440), match=' joy_soua120@yahoo.co.jp\n'>
# <re.Match object; span=(236, 241), match=' R@S\n'>
# None
# <re.Match object; span=(527, 551), match=' stephen@it.usyd.edu.au\n'>
# <re.Match object; span=(404, 430), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(369, 395), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(377, 403), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(488, 514), match=' SunocoSunOil@yahoo.co.jp\n'>
# <re.Match object; span=(488, 514), match=' SunocoSunOil@yahoo.co.jp\n'>
# None
# <re.Match object; span=(332, 359), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(609, 635), match=' onuoha5a2003@yahoo.co.jp\n'>
# <re.Match object; span=(524, 550), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(376, 431), match=' unlisted-recipients:; (no To-header on input)@ma>
# <re.Match object; span=(540, 563), match=' resumes@collarini.com\n'>
# <re.Match object; span=(492, 519), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(827, 854), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(822, 849), match=' undisclosed-recipients: ;\n'>
# None
# <re.Match object; span=(325, 347), match=' webmaster@aclweb.org\n'>
# <re.Match object; span=(658, 685), match=' undisclosed-recipients: ;\n'>
# None
# None
# <re.Match object; span=(255, 324), match=' "jamesbongani10015@latinmail.com" <jamesbongani1>
# None
# <re.Match object; span=(138, 143), match=' R@M\n'>
# <re.Match object; span=(229, 234), match=' R@S\n'>
# <re.Match object; span=(144, 149), match=' R@M\n'>
# <re.Match object; span=(101, 103), match=' \n'>
# <re.Match object; span=(170, 196), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(482, 509), match=' undisclosed-recipients: ;\n'>
# None
# None
# None
# <re.Match object; span=(598, 625), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(559, 585), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(572, 598), match=' undisclosed-recipients:;\n'>
# None
# <re.Match object; span=(631, 658), match=' undisclosed-recipients: ;\n'>
# <re.Match object; span=(412, 438), match=' undisclosed-recipients:;\n'>
# <re.Match object; span=(312, 338), match=' undisclosed-recipients:;\n'>
# None
# None
# None
# <re.Match object; span=(451, 477), match=' undisclosed-recipients:;\n'>

# %%
emails_df = pd.DataFrame(emails)
emails_df.head(10)
# Out:
#                     sender_email             sender_name  \
# 0    james_ngola2002@maktoob.com         MR. JAMES NGOLA
# 1   bensul2004nng@spinfinder.com         Mr. Ben Suleman
# 2           obong_715@epatra.com      PRINCE OBONG ELEME
# 3           obong_715@epatra.com      PRINCE OBONG ELEME
# 4             m_abacha03@www.com           Maryam Abacha
# 5         davidkuta@postmark.net              Kuta David
# 6         tunde_dosumu@lycos.com  Barrister tunde dosumu
# 7  william2244drallo@maktoob.com          William Drallo
# 8       abdul_817@rediffmail.com          MR USMAN ABDUL
# 9         barrister_td@lycos.com           Tunde  Dosumu
#
#         recipient_email recipient_name    date_sent  \
# 0  webmaster@aclweb.org      webmaster  31 Oct 2002
# 1                   R@M              R  31 Oct 2002
# 2  webmaster@aclweb.org      webmaster  31 Oct 2002
# 3  webmaster@aclweb.org      webmaster  31 Oct 2002
# 4                   R@M              R   1 Nov 2002
# 5   davidkuta@yahoo.com      davidkuta  02 Nov 2002
# 6                  None           None         None
# 7  webmaster@aclweb.org      webmaster   3 Nov 2002
# 8                   R@M              R  04 Nov 2002
# 9                  None           None         None
#
#                                       subject
# 0  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1          URGENT ASSISTANCE /RELATIONSHIP (P
# 2                             GOOD DAY TO YOU
# 3                             GOOD DAY TO YOU
# 4                      I Need Your Assistance
# 5                                 Partnership
# 6                            Urgent Attention
# 7                     URGENT BUSINESS PRPOSAL
# 8                                   THANK YOU
# 9                           Urgent Assistance

# %%
emails_df.to_csv(f"{student1_section}_{student1_BN}_{student2_section}_{student2_BN}.csv", index=False)
